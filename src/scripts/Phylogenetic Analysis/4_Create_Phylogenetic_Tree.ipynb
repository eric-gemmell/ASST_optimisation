# %% [markdown]
# <br><br>
# <h1 style="font-size:36px" align="center">Perform Phylogenetic Analysis</h1><br><br><br><br><br><br>

# %%
import os
base_dir = "../processed_sequences/"
redo_text = "-redo"
asr_text = "-asr"
method = "WAG+F+I+G4"

# %% [markdown]
# <h3 style="font-size:24px"> Define Parameters</h3><br>

# %%
input_MSA_filename = "../../data/ASST_processed_sequences/clustalo_no_cluster_20_12_2023/clustalo_no_cluster_95_ID_initial_MSA.fa"
output_dir = "../../data/ASST_processed_sequences/clustalo_no_cluster_20_12_2023/"
asr = True
redo = False


if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
print(f"Creating tree, using method {method}")
#Classic run:
# !iqtree2 -s $input_MSA_filename {(redo_text if redo else "")} -T 31 -m $method {(asr_text if asr else "")} -alrt 1000 --mlrate --undo
# Out:
# Creating tree, using method WAG+F+I+G4
# IQ-TREE multicore version 2.0.7 for Linux 64-bit built Jan 21 2022
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    37fc230909b8 (AVX2, FMA3, 62 GB RAM)
# Command: iqtree2 -s ../../data/ASST_processed_sequences/clustalo_no_cluster_20_12_2023/clustalo_no_cluster_95_ID_initial_MSA.fa -T 31 -m WAG+F+I+G4 -asr -alrt 1000 --mlrate --undo
# Seed:    153490 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Wed Dec 20 17:30:22 2023
# Kernel:  AVX+FMA - 31 threads (32 CPU cores detected)
#
# Reading alignment file ../../data/ASST_processed_sequences/clustalo_no_cluster_20_12_2023/clustalo_no_cluster_95_ID_initial_MSA.fa ... Fasta format detected
# Alignment most likely contains protein sequences
# WARNING: 7 sites contain only gaps or ambiguous characters.
# Alignment has 4083 sequences with 4623 columns, 4549 distinct patterns
# ...

# %% [markdown]
# <br><br>
# <h1 style="font-size:30px" align="center">If you just need to calculate the state file:</h1><br><br><br><br><br><br>

# %% [markdown]
# <h3 style="font-size:24px"> Define Parameters</h3><br>

# %%
input_MSA_filename = "../processed_sequences/clustal_hmm_5_per_cluster_18022023/seqs11.txt"
input_treefile = "../processed_sequences/clustal_hmm_5_per_cluster_18022023/seqs11.txt.treefile"
output_dir = "../processed_sequences/clustal_hmm_5_per_cluster_18022023/"



if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
# !iqtree2 -s $input_MSA_filename -te $input_treefile -T 47 -m $method -asr --undo

# %% [markdown]
# <br><br>
# <h1 style="font-size:30px" align="center">If you just need to calculate the support values</h1><br><br><br><br><br><br>

# %%
input_MSA_filename = "../processed_sequences/clustal_hmm_5_per_cluster_18022023/seqs11.txt"
input_treefile = "../processed_sequences/clustal_hmm_5_per_cluster_18022023/seqs11.txt.treefile"
output_dir = "../processed_sequences/clustal_hmm_5_per_cluster_18022023/"



if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
# !iqtree2 -s $input_MSA_filename -te $input_treefile -T 47 -m $method --abayes --undo

# %% [markdown]
# <br><br>
# <h1 style="font-size:30px" align="center">If you just want to date the tree</h1><br><br><br><br><br><br>

# %%
input_MSA_filename = "../processed_sequences/clustal_hmm_5_per_cluster_copy/seqs11.txt"
input_treefile = "../processed_sequences/clustal_hmm_5_per_cluster_copy/seqs11.txt.treefile"
output_dir = "../processed_sequences/clustal_hmm_5_per_cluster_copy/"
output_filename = "../processed_sequences/clustal_hmm_5_per_cluster_copy/date_file"



if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
# !./../external_scripts/iqtree2/build/iqtree2 -s $input_MSA_filename  -m $method --date $output_filename -te $input_treefile -T 47 --undo
# Out:
# NOTE: Continue analysis although a previous run already finished
# IQ-TREE multicore version 2.2.2.3 COVID-edition for Linux 64-bit built Mar  9 2023
# Developed by Bui Quang Minh, James Barbetti, Nguyen Lam Tung,
# Olga Chernomor, Heiko Schmidt, Dominik Schrempf, Michael Woodhams, Ly Trong Nhan.
#
# Host:    dc4b1604e884 (AVX2, FMA3, 251 GB RAM)
# Command: ./../external_scripts/iqtree2/build/iqtree2 -s ../processed_sequences/clustal_hmm_5_per_cluster_copy/seqs11.txt -m WAG+F+I+G4 --date ../processed_sequences/clustal_hmm_5_per_cluster_copy/date_file -te ../processed_sequences/clustal_hmm_5_per_cluster_copy/seqs11.txt.treefile -T 47 --undo
# Seed:    367658 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Thu Mar  9 20:22:13 2023
# Kernel:  AVX+FMA - 47 threads (48 CPU cores detected)
#
# ...

# %%
../../../processed_sequences/clustal_hmm_5_per_cluster_18022023/seqs11.txt --date ../../../processed_sequences/clustal_hmm_5_per_cluster_18022023/datefile_test -te ../../../processed_sequences/clustal_hmm_5_per_cluster_18022023/seqs11.txt.treefile
